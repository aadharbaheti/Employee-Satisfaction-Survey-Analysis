# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/Users/aadharbaheti/Downloads/archive-5/Employee Attrition.csv')

# %%
data
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
data.describe()
# Out:
#              Emp ID  satisfaction_level  last_evaluation  number_project  \
# count  14999.000000        14999.000000     14999.000000    14999.000000
# mean    7500.000000            0.612834         0.716102        3.803054
# std     4329.982679            0.248631         0.171169        1.232592
# min        1.000000            0.090000         0.360000        2.000000
# 25%     3750.500000            0.440000         0.560000        3.000000
# 50%     7500.000000            0.640000         0.720000        4.000000
# 75%    11249.500000            0.820000         0.870000        5.000000
# max    14999.000000            1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# ...

# %%
null_values = data.isnull().sum()

print(null_values)
# Out:
# Emp ID                   788
# satisfaction_level       788
# last_evaluation          788
# number_project           788
# average_montly_hours     788
# time_spend_company       788
# Work_accident            788
# promotion_last_5years    788
# dept                     788
# salary                   788
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14999 entries, 0 to 15786
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Emp ID                 14999 non-null  float64
#  1   satisfaction_level     14999 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  float64
#  4   average_montly_hours   14999 non-null  float64
#  5   time_spend_company     14999 non-null  float64
#  6   Work_accident          14999 non-null  float64
#  7   promotion_last_5years  14999 non-null  float64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(8), object(2)
# memory usage: 1.3+ MB

# %%
# Box plot for 'satisfaction_level'
plt.figure(figsize=(8, 6))
sns.boxplot(y='satisfaction_level', data=data)
plt.title('Box Plot of Satisfaction Level')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 6))

# Box plot for 'number_project'
plt.subplot(1, 3, 1)
sns.boxplot(y='number_project', data=data)
plt.title('Box Plot of Number of Projects')

# Box plot for 'average_montly_hours'
plt.subplot(1, 3, 2)
sns.boxplot(y='average_montly_hours', data=data)
plt.title('Box Plot of Average Monthly Hours')

# Box plot for 'time_spend_company'
plt.subplot(1, 3, 3)
sns.boxplot(y='time_spend_company', data=data)
plt.title('Box Plot of Time Spent in the Company')

# Adjust layout for better visualization
plt.tight_layout()


plt.show()

# %%
outlier_threshold = 6  
outliers = data[data['time_spend_company'] > outlier_threshold]
print(outliers)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 11007  11008.0                0.49             0.67             2.0
# 11008  11009.0                0.92             0.99             3.0
# 11009  11010.0                0.81             0.55             4.0
# 11010  11011.0                0.62             0.91             3.0
# 11011  11012.0                0.21             0.70             3.0
# ...        ...                 ...              ...             ...
# 14993  14206.0                0.22             0.94             3.0
# 14994  14207.0                0.90             0.55             3.0
# 14995  14208.0                0.74             0.95             5.0
# 14996  14209.0                0.85             0.54             3.0
# 14997  14210.0                0.33             0.65             3.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 11007                 190.0                 8.0            0.0
# ...

# %%
# Count plot for 'Work_accident'
plt.figure(figsize=(8, 6))
sns.countplot(x='Work_accident', data=data)
plt.title('Count Plot of Work Accidents')
plt.show()

# %%
# Count plot for 'dept'
plt.figure(figsize=(8, 6))
sns.countplot(y='dept', data=data)
plt.title('Count Plot of Department')
plt.yticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Count plot for 'salary'
plt.figure(figsize=(8, 6))
sns.countplot(y='salary', data=data)
plt.title('Count Plot of Salary')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plots
sns.set(style="whitegrid")

# Box plot for department (dept)
plt.figure(figsize=(10, 6))
sns.boxplot(x='dept', y='satisfaction_level', data=data)
plt.title('Satisfaction Level by Department')
plt.xticks(rotation=45)
plt.show()

# %%
# Box plot for salary
plt.figure(figsize=(8, 6))
sns.boxplot(x='salary', y='satisfaction_level', data=data)
plt.title('Satisfaction Level by Salary')
plt.show()

# %%
from scipy.stats import f_oneway

low_salary = data[data['salary'] == 'low']['average_montly_hours']
medium_salary = data[data['salary'] == 'medium']['average_montly_hours']
high_salary = data[data['salary'] == 'high']['average_montly_hours']

f_statistic, p_value = f_oneway(low_salary, medium_salary, high_salary)

if p_value < 0.05:
    print(f"The one-way ANOVA test for 'average_monthly_hours' is statistically significant (p-value={p_value}).")
else:
    print(f"The one-way ANOVA test for 'average_monthly_hours' is not statistically significant (p-value={p_value}).")
# Out:
# The one-way ANOVA test for 'average_monthly_hours' is not statistically significant (p-value=0.6323271153144614).

# %%
from scipy.stats import f_oneway

# Extract the 'number_project' data for each salary category
low_salary_projects = data[data['salary'] == 'low']['number_project']
medium_salary_projects = data[data['salary'] == 'medium']['number_project']
high_salary_projects = data[data['salary'] == 'high']['number_project']

# Perform one-way ANOVA test
f_statistic, p_value = f_oneway(low_salary_projects, medium_salary_projects, high_salary_projects)

if p_value < 0.05:
    print(f"The one-way ANOVA test for 'number_project' is statistically significant (p-value={p_value}).")
else:
    print(f"The one-way ANOVA test for 'number_project' is not statistically significant (p-value={p_value}).")
# Out:
# The one-way ANOVA test for 'number_project' is not statistically significant (p-value=0.45808513818559393).

# %%
from scipy.stats import f_oneway

# Extract 'last_evaluation' data for each salary category
low_salary_evaluation = data[data['salary'] == 'low']['last_evaluation']
medium_salary_evaluation = data[data['salary'] == 'medium']['last_evaluation']
high_salary_evaluation = data[data['salary'] == 'high']['last_evaluation']

# Perform one-way ANOVA test
f_statistic, p_value = f_oneway(low_salary_evaluation, medium_salary_evaluation, high_salary_evaluation)

if p_value < 0.05:
    print(f"The one-way ANOVA test for 'last_evaluation' is statistically significant (p-value={p_value}).")
else:
    print(f"The one-way ANOVA test for 'last_evaluation' is not statistically significant (p-value={p_value}).")
# Out:
# The one-way ANOVA test for 'last_evaluation' is statistically significant (p-value=0.04089896616654419).

# %%
# Create a contingency table for 'salary' and 'dept'
contingency_table = pd.crosstab(data['salary'], data['dept'])


# Create a clustered bar chart
contingency_table.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Clustered Bar Chart of Salary vs. Department')
plt.xlabel('Salary Category')
plt.ylabel('Count')
plt.legend(title='Department', loc='upper right')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
from scipy.stats import kruskal

# Extract satisfaction level data for each salary category
low_salary_satisfaction = data[data['salary'] == 'low']['satisfaction_level']
medium_salary_satisfaction = data[data['salary'] == 'medium']['satisfaction_level']
high_salary_satisfaction = data[data['salary'] == 'high']['satisfaction_level']

# Perform the Kruskal-Wallis test
statistic, p_value = kruskal(low_salary_satisfaction, medium_salary_satisfaction, high_salary_satisfaction)

if p_value < 0.05:
    print(f"The Kruskal-Wallis test is statistically significant (p-value={p_value}).")
    print("There is a significant relationship between 'salary' and 'satisfaction_level'.")
else:
    print(f"The Kruskal-Wallis test is not statistically significant (p-value={p_value}).")
    print("There is no significant relationship between 'salary' and 'satisfaction_level'.")
# Out:
# The Kruskal-Wallis test is statistically significant (p-value=1.947690141323984e-07).
# There is a significant relationship between 'salary' and 'satisfaction_level'.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Creating a pivot table to calculate the average satisfaction level for each combination
pivot_table = data.pivot_table(index='dept', columns='salary', values='satisfaction_level', aggfunc='mean')


plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Average Satisfaction Level by Salary Level and Department')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV



# Perform one-hot encoding for categorical variables
data = pd.get_dummies(data, columns=['Work_accident', 'salary', 'dept'], drop_first=True)

# Split the data into features (X) and the target variable (y)
X = data.drop(['satisfaction_level','Emp ID'], axis=1)  # Dropping target variable
y = data['satisfaction_level']  # Target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.metrics import r2_score

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print(f"R-squared: {r_squared}")
# Out:
# R-squared: 0.4816636880063896

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error


# Create a Random Forest Regressor model with default parameters
model = RandomForestRegressor(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 0.1265169937846721

# %%
import matplotlib.pyplot as plt

# Scatterplot of actual vs. predicted satisfaction levels
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual Satisfaction Levels")
plt.ylabel("Predicted Satisfaction Levels")
plt.title("Actual vs. Predicted Satisfaction Levels")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get feature importances from the model
feature_importances = model.feature_importances_

# Get the names of the features (column names of X)
feature_names = X.columns

# Sort the features by importance in descending order
sorted_indices = np.argsort(feature_importances)[::-1]
sorted_feature_importances = feature_importances[sorted_indices]
sorted_feature_names = feature_names[sorted_indices]

# Create a bar plot of feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(sorted_feature_importances)), sorted_feature_importances)
plt.xticks(range(len(sorted_feature_importances)), sorted_feature_names, rotation=90)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importance")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Select the tree you want to plot (e.g., the first tree)
selected_tree = model.estimators_[0]  # Adjust the index as needed

# Set the maximum depth for visualization (5 branches)
max_depth = 3

# Create a figure for the tree plot
plt.figure(figsize=(12, 8))

# Plot the selected tree with a limited depth
plot_tree(selected_tree, max_depth=max_depth, feature_names=X.columns, filled=True, rounded=True, fontsize=8)

# Show the tree plot
plt.show()
